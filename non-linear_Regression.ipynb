# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("Ice_cream selling data.csv")
df.head()
# Out:
#    Temperature (°C)  Ice Cream Sales (units)
# 0         -4.662263                41.842986
# 1         -4.316559                34.661120
# 2         -4.213985                39.383001
# 3         -3.949661                37.539845
# 4         -3.578554                32.284531

# %%
x = df[['Temperature (°C)']]
y = df['Ice Cream Sales (units)']

plt.plot(x,y)

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,train_size=0.8,random_state=42)

xtest
# Out:
#     Temperature (°C)
# 13         -1.818938
# 45          3.704057
# 47          4.133534
# 44          3.610778
# 17         -0.773330
# 27          1.024181
# 26          0.874905
# 25          0.693599
# 31          1.850552
# 19         -0.149635

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.score(xtest,ytest)
# Out:
# -0.5751270190188227

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2)

xpoly = poly.fit_transform(xtrain)

model.fit(xpoly,ytrain)
# Out:
# LinearRegression()

# %%
xtest_poly = poly.transform(xtest)

pre = model.predict(xtest_poly)

pre
# Out:
# array([10.24499852, 25.82807714, 31.8241041 , 24.61704203,  4.43380256,
#         4.00785672,  3.58277491,  3.17865087,  7.86990452,  2.91591368])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

mean_squared_error(xtest,pre)

mean_absolute_error(xtest,pre)

r2_score(xtest,pre)
# Out:
# -52.539289391866

# %%
plt.scatter(xtest,pre)
plt.scatter(x,y)
